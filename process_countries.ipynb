# %%
# input a list of all possible locations
# output a json file that contains a dict of location to its actual country
import geonamescache
import json
import unidecode

gc = geonamescache.GeonamesCache()

# %%
def get_country_from_city(city: str) -> str:
    """If city is a recognized city, return the country the city is in."""

    search_result = gc.search_cities(city, contains_search=True)
    if search_result:
        return search_result[0]["countrycode"]
    else:
        return ""


def is_us_state(state: str, states_list: list) -> bool:
    """Given a list of valid US states, return True if input state is a valid US state.
    State input is lowercase."""

    return state in states_list


def get_country_code_from_country_name(name: str, countries_dict: dict) -> str:
    """Given a lowercase country name, return a country code if the country name is valid,
    an empty string otherwise."""

    # format country to have a capitalized name
    name = name.title()

    country_info = countries_dict.get(name)

    if not country_info:
        return ""

    code = country_info.get("iso")

    if code:
        return code
    else:
        return ""


def get_country_from_string(string: str, countries_list: list, states_list: str, countries_dict: dict) -> str:
    """Given an input string, return the associated country code if country can be found."""

    string = string.lower().strip()

    # check if full string contains a country
    for country in countries_list:
        # print(country)
        if country in string:
            return get_country_code_from_country_name(country, countries_dict)

    # check if full string is a city
    city = get_country_from_city(string)
    if city:
        return city

    # check by token
    tokens = string.split()

    for token in tokens:        
        if is_us_state(token, states_list):
            return "US"
        
        country = get_country_from_city(token)
        if country:
            return country

    return ""


def create_country_key_dict(location_list: list) -> dict:
    """Given a list of location strings, create a dictionary mapping 
    each location to the country it is in. If no country is found, 
    assign it an empty string."""

    country_names = list(gc.get_countries_by_names().keys())
    country_names = [country.lower() for country in country_names]

    state_names = list(gc.get_us_states_by_names().keys())
    state_names = [state.lower() for state in state_names]

    countries_dict = gc.get_countries_by_names()

    country_key = dict()
    
    for location in location_list:

        current_country = ""
        country = get_country_from_string(unidecode.unidecode(location), country_names, state_names, countries_dict)

        if country:
            country_key.update({location: country})
        else:
            country_key.update({location: ""})

    return country_key

# %%
with open("all_countries.json", "r") as fp:
    loaded_countries = json.load(fp)

country_names = [country.lower() for country in list(gc.get_countries_by_names().keys())]
state_names = list(gc.get_us_states_by_names().keys())
cd = gc.get_countries_by_names()

# print(get_country_from_string(" South Africa", country_names, state_names, cd))

confirmed_countries = []

for c in loaded_countries:
    result = get_country_from_string(c, country_names, state_names, cd)
    if result:
        confirmed_countries.append(result)
    # else:
    #     confirmed_countries.append("NAN")

print(f"number of confirmed countries: {len(confirmed_countries)}")
print(f"number of input countries: {len(loaded_countries)}")
print(f"fraction of countries confirmed: {len(confirmed_countries) / len(loaded_countries)}")

print(confirmed_countries)
# Out:
# number of confirmed countries: 1026
# number of input countries: 1290
# fraction of countries confirmed: 0.7953488372093023
# ['US', 'IT', 'AZ', 'IT', 'MX', 'BE', 'FR', 'IR', 'MX', 'CL', 'IN', 'VE', 'ES', 'ZA', 'FR', 'SE', 'AD', 'HU', 'CA', 'VE', 'FR', 'AT', 'IT', 'AR', 'AD', 'AU', 'AE', 'IT', 'AE', 'FR', 'CO', 'FI', 'FR', 'BF', 'NL', 'CL', 'MX', 'CO', 'AE', 'IN', 'FI', 'MY', 'UA', 'EE', 'UA', 'TR', 'AE', 'AE', 'BO', 'JE', 'AT', 'IN', 'MX', 'MX', 'BG', 'CO', 'NL', 'CO', 'AR', 'SE', 'BO', 'US', 'AR', 'AR', 'US', 'AD', 'US', 'DE', 'CA', 'CO', 'IT', 'RU', 'US', 'BS', 'AR', 'AD', 'FI', 'AM', 'FR', 'IN', 'FR', 'DE', 'IN', 'AD', 'BO', 'FR', 'DE', 'AE', 'VE', 'PA', 'MX', 'TZ', 'JP', 'IT', 'FI', 'MX', 'UA', 'BE', 'FR', 'AE', 'EC', 'MX', 'FR', 'IE', 'BE', 'AD', 'AD', 'CU', 'BA', 'NP', 'VE', 'AI', 'AF', 'CO', 'IT', 'AR', 'AD', 'CA', 'VE', 'AE', 'US', 'SE', 'CA', 'MX', 'FI', 'BD', 'IT', 'EG', 'MX', 'MX', 'AE', 'AD', 'AL', 'US', 'AD', 'AD', 'PY', 'AR', 'PA', 'MX', 'MX', 'IT', 'RU', 'DM', 'BR', 'MX', 'FR', 'GY', 'RU', 'IT', 'KR', 'ID', 'MX', 'CO', 'IE', 'IT', 'GB', 'AR', 'AF', 'AE', 'FI', 'US', 'AF', 'FI', 'MX', 'AE', 'AU', 'UA', 'AO', 'MX', 'AD', 'FR', 'AZ', 'CO', 'IT', 'BR', 'IT', 'AD', 'MA', 'BE', 'AU', 'AF', 'VE', 'AR', 'AI', 'AF', 'RU', 'FI', 'IT', 'MX', 'AE', 'MX', 'MX', 'AD', 'BE', 'VE', 'CO', 'AI', 'CU', 'CR', 'AT', 'MX', 'CA', 'ES', 'MX', 'SE', 'VE', 'SE', 'DK', 'AR', 'JE', 'AF', 'AD', 'BR', 'MX', 'VE', 'UA', 'AE', 'IN', 'IT', 'BE', 'IT', 'CA', 'US', 'PA', 'IT', 'AF', 'UA', 'DE', 'DZ', 'CO', 'DZ', 'DZ', 'DE', 'BR', 'SE', 'AR', 'IT', 'IN', 'AO', 'BE', 'IN', 'AR', 'AT', 'CU', 'MX', 'AR', 'IT', 'RU', 'CO', 'IQ', 'AF', 'MX', 'AR', 'BR', 'AT', 'IT', 'AO', 'AW', 'AE', 'CR', 'AR', 'IT', 'SV', 'GB', 'MX', 'AD', 'MX', 'MX', 'FR', 'FR', 'CO', 'VE', 'AU', 'IT', 'AD', 'ES', 'CA', 'AE', 'AD', 'AE', 'DE', 'PR', 'TN', 'AE', 'BR', 'AL', 'BG', 'MX', 'NL', 'BT', 'IT', 'FR', 'US', 'AD', 'ID', 'GB', 'MX', 'FI', 'NI', 'US', 'AR', 'IT', 'BR', 'AZ', 'FR', 'MX', 'AD', 'PL', 'IN', 'GB', 'MX', 'MX', 'MX', 'IT', 'AR', 'AD', 'CN', 'AO', 'DK', 'CO', 'AD', 'AU', 'ES', 'TN', 'AF', 'AO', 'AF', 'CL', 'US', 'FR', 'GR', 'TT', 'AR', 'AD', 'AU', 'IT', 'IT', 'CA', 'IN', 'CA', 'US', 'NL', 'ES', 'IT', 'FR', 'UY', 'MX', 'IN', 'UA', 'CL', 'AD', 'ET', 'KZ', 'FR', 'FR', 'IT', 'US', 'FR', 'BR', 'AD', 'AE', 'BR', 'AD', 'AR', 'CA', 'AD', 'FR', 'AD', 'VE', 'ID', 'MX', 'MX', 'NI', 'AE', 'MX', 'IT', 'CO', 'RU', 'VE', 'BR', 'RU', 'AD', 'AD', 'AF', 'AE', 'GH', 'CO', 'CO', 'FI', 'VE', 'DE', 'IN', 'CA', 'GH', 'AF', 'BE', 'MX', 'VE', 'AU', 'AR', 'DE', 'NI', 'FI', 'MX', 'BG', 'AU', 'FR', 'DK', 'AD', 'AD', 'HU', 'RU', 'AR', 'MX', 'RO', 'VE', 'AD', 'MX', 'AO', 'CA', 'EC', 'IT', 'CA', 'CU', 'AI', 'ES', 'AE', 'FR', 'IT', 'UG', 'SV', 'MX', 'AE', 'AE', 'PT', 'GT', 'SO', 'IT', 'CH', 'AE', 'FI', 'AU', 'AD', 'FR', 'FR', 'VE', 'VE', 'BE', 'AR', 'VE', 'AD', 'MX', 'AE', 'NL', 'AM', 'IT', 'VE', 'CH', 'AD', 'AG', 'AD', 'KE', 'FI', 'MX', 'CO', 'VE', 'FR', 'FR', 'DE', 'FR', 'IT', 'IT', 'AD', 'GR', 'IT', 'CU', 'IN', 'AD', 'AR', 'AE', 'IT', 'FR', 'AM', 'US', 'IN', 'CL', 'DM', 'TT', 'VE', 'NL', 'AR', 'PE', 'AD', 'CU', 'JP', 'IT', 'ZW', 'IT', 'FR', 'VE', 'US', 'BE', 'NL', 'VE', 'MX', 'MX', 'FR', 'BE', 'NL', 'US', 'CA', 'CO', 'CU', 'IT', 'AD', 'AR', 'ES', 'SE', 'JP', 'AD', 'FR', 'IN', 'CO', 'AD', 'IT', 'AD', 'VE', 'GB', 'FI', 'IT', 'JP', 'CO', 'AE', 'OM', 'MX', 'MX', 'IT', 'AD', 'IN', 'AO', 'MX', 'MX', 'BR', 'IT', 'US', 'MX', 'CU', 'AD', 'RU', 'IL', 'BR', 'FR', 'FR', 'CL', 'VE', 'EC', 'US', 'ZA', 'CO', 'FR', 'AU', 'BR', 'GB', 'IN', 'AZ', 'AR', 'NL', 'UA', 'AE', 'BE', 'NI', 'AR', 'AR', 'DM', 'CA', 'US', 'IT', 'US', 'FR', 'AE', 'IT', 'MX', 'AR', 'PA', 'CU', 'AR', 'ES', 'AU', 'FR', 'HR', 'VE', 'CU', 'FR', 'IT', 'US', 'AE', 'US', 'AG', 'GT', 'US', 'BR', 'AR', 'MX', 'PK', 'CA', 'SE', 'AO', 'IT', 'FR', 'FR', 'UY', 'AR', 'DZ', 'AE', 'BR', 'PL', 'FR', 'CD', 'MX', 'AE', 'AD', 'CA', 'MX', 'IN', 'IN', 'AD', 'IN', 'MX', 'IR', 'AU', 'FR', 'AD', 'MX', 'AD', 'US', 'AD', 'AR', 'CO', 'CO', 'ZA', 'EC', 'NO', 'AU', 'VE', 'KE', 'IT', 'MX', 'IN', 'IT', 'AD', 'IT', 'DE', 'GB', 'BR', 'UA', 'AD', 'US', 'MX', 'MX', 'FI', 'IT', 'MX', 'AF', 'ES', 'VE', 'MX ...

# %%
with open("all_countries.json", "r") as fp:
    loaded_countries = json.load(fp)

key = create_country_key_dict(loaded_countries)

print(
    key
)

with open("location_key.json", "w") as fp:
    json.dump(key, fp)
# Out:
# {'Evanston': 'US', 'Rusia ': 'IT', 'caba ': 'AZ', 'Sudamérica': '', 'Rome, Lazio': 'IT', 'Coacalco, Mexico': 'MX', 'Mars': 'BE', 'Antibes ☀': 'FR', 'Jambudweep': '', 'Islamic Republic of Iran': 'IR', 'Pachuca de Soto, Hidalgo': 'MX', 'Chile': 'CL', 'Everywhere around your mind.': 'IN', 'Chacao, Venezuela': 'VE', 'La laguna': 'ES', 'Johannesburg, South Africa': 'ZA', 'FRANCE': 'FR', 'Stockholm, Sverige': 'SE', 'Langley, VA (Adjacent)': 'AD', 'Polcenigo, Friuli-Venezia Giul': 'HU', 'Estados Unidos': '', 'Liège, Belgique': '', 'mondo': 'CA', 'Estado Trujillo Venezuela.': 'VE', 'QRO': 'FR', 'Vienna, Austria': 'AT', 'Rome, Italy': 'IT', 'COMO 🇲🇽 NO HAY DOS. DF.': 'AR', 'l': 'AD', 'Somewhere off Sevastopol coast': 'AU', 'Somewhere in the world': 'AE', 'Piossasco': 'IT', 'in giro': 'AE', "Sous l'escalier, France": 'FR', 'Bogota': 'CO', 'Helsinki Finland': 'FI', 'France Occitanie': 'FR', 'Burkina Faso': 'BF', 'Schagen The Netherlands': 'NL', 'Wano': 'CL', 'Durango, México': 'MX', 'Tierra Perdida.': 'CO', 'Centro, Tabasco': '', "🌍🇪🇺🇫🇮 'ɹǝpun ᴉʞuᴉslǝH": '', 'Massachusetts, USA': 'AE', 'India': 'IN', 'Helsinki, FInland': 'FI', 'Tukholma, Szwecja': '', 'Kuala-Lumpur': 'MY', '#Kyiv, #Ukraine': 'UA', 'Assisi': '', 'भारत': '', 'Estonia': 'EE', 'Ungeimpft Ungetestet Unbeugsam': '', 'Kiev': 'UA', 'Istanbul, Turkey': 'TR', 'normandie ': '', 'California, USA': 'AE', 'Ohio, USA': 'AE', 'SUCRE': 'BO', 'NEW JERSEY': 'JE', '🇨🇦 10 minutes from USA': 'AT', 'Bharat': 'IN', 'Mexico ': 'MX', 'Campeche, México': 'MX', 'Dans mon magnifique pays.': 'BG', 'Cali, Colombia': 'CO', 'The Netherlands': 'NL', 'Bogota Colombia   ': 'CO', 'Nel Nulla': 'AR', 'Öckerö, Sverige': 'SE', 'Bolivia': 'BO', 'Terrest. World at the moment': 'US', 'aquí y allá...': 'AR', 'Ciudad Autónoma de Buenos Aire': 'AR', 'Heaven': 'US', 'La Spezia, Liguria': 'AD', 'SPOUTIBLE': '', 'Región Centro-Occidental': 'AU', 'Pennsylvania & Colorado, USA': 'US', 'Germany, France': 'DE', 'Niagara Falls, NY': 'CA', 'Planet Earth': 'CO', 'Venezia, Veneto': 'IT', 'Euroopan laidalla': '', 'Arzamas-16': 'RU', '/dev/random': '', 'Oregon': 'US', 'Cruising Bahamas, FL, TX, PA': 'BS', 'Ciudad De México.': 'MX', 'Oswego, NY': 'AD', 'Central Finland, Finland': 'FI', 'Loreto, Baja California Sur': 'AM', 'París, Francia': 'FR', 'Indiana': 'IN', 'Tremblay-en-France, France': 'FR', 'Fuck Capitalism': '', '💛💙Munich/Germany💛💙': 'DE', 'Kolkata, Bharat ': 'IN', 'Brooklyn, N.Y. ,USA': '', 'Piemonte': '', 'Le Maquis ': 'AD', 'Gurun, Kedah': '', 'Pisa 🇵🇸🌠': 'BO', 'Charenton-le-Pont, France': 'FR', 'México, D. F. ': 'MX', 'Polska, Mazowsze': '', 'Sassari, Sardegna': '', ' Dubai, United Arab Emirates ': 'AE', 'Venezuela 🇻🇪': 'VE', 'panama': 'PA', 'Aguascalientes, México': 'MX', 'Dar es Salaam, Tanzania': 'TZ', 'Japan, Paris': 'JP', 'Sicilia, Italia': 'IT', 'Helsinki, Finland': 'FI', 'Guerrero, México': 'MX', 'Ukraine, Bucha': 'UA', 'Here & now': 'BE', 'Guînes, France': 'FR', 'Montalto di Castro, Lazio': 'AE', 'Quito, Ecuador': 'EC', 'ciudad de México ': 'MX', 'Space': '', 'Nevers, Francia': 'FR', 'Genève, Suisse': '', 'Ireland & Lanzarote ': 'IE', 'Piding, OBB': 'BE', 'Le Fenua': 'AD', 'NO MES - NO IUS SOLI': 'AD', 'La Habana': 'CU', 'LIMA': 'BA', 'Kathmandu': 'NP', 'VENEZUELA LIBRE Y SOBERANA': 'VE', 'Where the Red Fern Grows ': 'AI', 'val de marne': 'AF', 'Acacías, Colombia': 'CO', 'Firenze⚜️🇮🇹': 'IT', '人身売買された人間として万が一に備え公開遺言を書いておきます': 'AF', 'Sempre': '', 'Provincie': 'IT', 'Miguel Hidalgo, Distrito Feder': 'AR', 'De CDMX para el Mundo.': 'AD', 'Under your bed': 'CA', 'GUARENAS': 'VE', 'Pirkanmaa, Suomi': '', 'Seattle, WA': 'AE', 'Miami - España': 'US', 'Jonkoping, Sweden, Tellus': 'SE', 'MONDO': 'CA', ' Cd. Obregón, Sonora México.': 'MX', 'Tampere, Finland': 'FI', 'Dhaka, Bangladesh': 'BD', 'ルルイエ': '', 'Roma, Lazio': 'IT', 'Egypt, PA': 'EG', 'Oaxaca de Juárez, Oaxaca': 'MX', 'mexico': 'MX', 'Texas, USA': 'AE', 'ni idea': 'AD', 'Away from this f*cking Europe': 'AL', '40.000 Feet': 'US', 'Macondo': '', 'Desde la casa del s ...
